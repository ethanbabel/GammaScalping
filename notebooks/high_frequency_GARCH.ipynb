# %% [markdown]
# GARCH Volatility Forcasting

# %%
import yfinance as yf
from datetime import datetime, timedelta
import pandas as pd
import matplotlib.pyplot as plt
from arch import arch_model
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import numpy as np

# %%
start = datetime(2024, 9, 29, 0, 0, 0)
end = datetime(2024, 10, 5, 11, 59, 59)

spy = yf.Ticker("SPY")
hst = spy.history(start=start, end=end, interval="1m")

returns = 100 * hst.Close.pct_change().dropna()

# %%
plt.figure(figsize=(10,4))
plt.plot(returns)
plt.ylabel('Pct Return', fontsize=16)
plt.title('SPY Returns', fontsize=20)
# Out:
# Text(0.5, 1.0, 'SPY Returns')

# %%
plot_pacf(returns**2)
plt.show()

# %%
start = datetime(2024, 9, 29, 0, 0, 0)
end = datetime(2024, 10, 5, 11, 59, 59)

spy = yf.Ticker("SPY")
hst = spy.history(start=start, end=end, interval="15m")

returns = 100 * hst.Close.pct_change().dropna()

# %%
plt.figure(figsize=(10,4))
plt.plot(returns)
plt.ylabel('Pct Return', fontsize=16)
plt.title('SPY Returns', fontsize=20)
# Out:
# Text(0.5, 1.0, 'SPY Returns')

# %%
plot_pacf(returns**2)
plt.show()

# %%
start = datetime(2024, 9, 1, 0, 0, 0)
end = datetime(2024, 9, 30, 11, 59, 59)

spy = yf.Ticker("SPY")
hst = spy.history(start=start, end=end, interval="30m")

returns = 100 * hst.Close.pct_change().dropna()

# %%
plt.figure(figsize=(10,4))
plt.plot(returns)
plt.ylabel('Pct Return', fontsize=16)
plt.title('SPY Returns', fontsize=20)
# Out:
# Text(0.5, 1.0, 'SPY Returns')

# %%
plot_pacf(returns**2)
plt.show()
